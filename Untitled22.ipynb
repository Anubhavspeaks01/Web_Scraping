# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)

# %%
from bs4 import BeautifulSoup

# file read karo
with open('smartprix.html', 'r', encoding='utf-8') as f:
    html = f.read()

# parse + format
soup = BeautifulSoup(html, 'html.parser')

# new formatted file save
with open('smartprix_formatted.html', 'w', encoding='utf-8') as f:
    f.write(soup.prettify())

# %%
soup = BeautifulSoup(html,'lxml')
import numpy as np
import pandas as pd

# %%
containers = soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'})

# %%
names = []
prices = []
ratings = []
sim = []
processor = []
ram = []
battery = []
display = []
camera = []
card = []
os = []

for i in soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'}):
    try:
        names.append(i.find('h2').text)
    except:
        names.append(np.nan)
    try:
        prices.append(i.find('span',{'class':'price'}).text)
    except:
        price.append(np.nan)
    try:
        ratings.append(i.find('div',{'class':'score rank-2-bg'}).find('b').text)
    except:
        ratings.append(np.nan)

    x = i.find('ul',{'class':'sm-feat specs'}).find_all('li')
    try:
        sim.append(x[0].text)
    except:
        sim.append(np.nan)
    try:
        processor.append(x[1].text)
    except:
        processor.append(np.nan)
    try:
        ram.append(x[2].text)
    except:
        ram.append(np.nan)
    try:
        battery.append(x[3].text)
    except:
        battery.append(np.nan)
    try:
        display.append(x[4].text)
    except:
        display.append(np.nan)
    try:
        camera.append(x[5].text)
    except:
        camera.append(np.nan)
    try:
        card.append(x[6].text)
    except:
        card.append(np.nan)
    try:
        os.append(x[7].text)
    except:
        os.append(np.nan)

# %%
len(names)
# Out:
# 1020

# %%
len(prices)
# Out:
# 1020

# %%
len(ratings)
# Out:
# 1020

# %%
df = pd.DataFrame({
    'model':names,
    'price':prices,
    'rating':ratings
})

# %%
df = pd.DataFrame({
    'model':names,
    'price':prices,
    'rating':ratings,
    'sim':sim,
    'processor':processor,
    'ram':ram,
    'battery':battery,
    'display':display,
    'camera':camera,
    'card':card,
    'os':os
})

# %%
df
# Out:
#                                     model      price rating  \
# 0                             Vivo T5x 5G    ₹18,999     64
# 1                Samsung Galaxy S25 Ultra  ₹1,10,999    NaN
# 2                   Samsung Galaxy S25 FE    ₹50,990     77
# 3                         Poco X8 Pro Max    ₹42,999    NaN
# 4                               iQOO Z11x    ₹18,998     63
# ...                                   ...        ...    ...
# 1015                  Foneme FM-2 Mini 27       ₹799    NaN
# 1016        Oppo A5x 4G (4GB RAM + 128GB)    ₹10,941     50
# 1017  Realme 13 Pro 5G (12GB RAM + 256GB)    ₹25,499     64
# 1018      Realme 15 5G (12GB RAM + 256GB)    ₹29,954     67
# 1019       Realme 15 5G (8GB RAM + 256GB)    ₹28,490     66
#
#                                                  sim  \
# 0     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 1      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 2      Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 3     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 4                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...                                              ...
# 1015                                        Dual Sim
# 1016      Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster
# 1017              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1018              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1019              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                               processor  \
# 0     Dimensity 7400 Turbo, Octa Core, 2.6 GHz Proce...
# 1     Snapdragon 8 Elite for Galaxy, Octa Core, 4.47...
# 2             Exynos 2400, Deca Core, 3.2 GHz Processor
# 3        Dimensity 9500s, Octa Core, 3.73 GHz Processor
# 4     Dimensity 7400 Turbo, Octa Core, 2.6 GHz Proce...
# ...                                                 ...
# 1015                                  1.4 MHz Processor
# 1016  Snapdragon 6s 4G Gen1, Octa Core, 2.1 GHz Proc...
# 1017   Snapdragon 7s Gen2, Octa Core, 2.4 GHz Processor
# 1018           Dimensity 7300 Plus, Octa Core Processor
# 1019           Dimensity 7300 Plus, Octa Core Processor
#
#                             ram                                   battery  \
# 0      6 GB RAM, 128 GB inbuilt   7200 mAh Battery with 44W Fast Charging
# 1     12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 45W Fast Charging
# 2      8 GB RAM, 128 GB inbuilt   4900 mAh Battery with 45W Fast Charging
# 3     12 GB RAM, 256 GB inbuilt  9000 mAh Battery with 100W Fast Charging
# 4      6 GB RAM, 128 GB inbuilt   7200 mAh Battery with 44W Fast Charging
# ...                         ...                                       ...
# 1015   32 MB RAM, 32 MB inbuilt                          1000 mAh Battery
# 1016   4 GB RAM, 128 GB inbuilt   6000 mAh Battery with 45W Fast Charging
# 1017  12 GB RAM, 256 GB inbuilt   5200 mAh Battery with 45W Fast Charging
# 1018  12 GB RAM, 256 GB inbuilt   7000 mAh Battery with 80W Fast Charging
# 1019   8 GB RAM, 256 GB inbuilt   7000 mAh Battery with 80W Fast Charging
#
#                                                 display  \
# 0     6.76 inches, 1080 x 2344 px, 120 Hz Display wi...
# 1     6.9 inches, 1440 x 3120 px, 120 Hz Display wit...
# 2     6.7 inches, 1080 x 2340 px, 120 Hz Display wit...
# 3     6.83 inches, 1280 x 2772 px, 120 Hz Display wi...
# 4     6.76 inches, 1080 x 2344 px, 120 Hz Display wi...
# ...                                                 ...
# 1015                  0.66 inches, 120 x 240 px Display
# 1016  6.67 inches, 720 x 1604 px, 90 Hz Display with...
# 1017  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 1018  6.8 inches, 1280 x 2800 px, 144 Hz Display wit...
# 1019  6.8 inches, 1280 x 2800 px, 144 Hz Display wit...
#
#                                                  camera  \
# 0           50 MP + 2 MP Dual Rear & 32 MP Front Camera
# 1                 200 MP Quad Rear & 12 MP Front Camera
# 2     50 MP + 12 MP + 8 MP Triple Rear & 12 MP Front...
# 3           50 MP + 8 MP Dual Rear & 20 MP Front Camera
# 4           50 MP + 2 MP Dual Rear & 32 MP Front Camera
# ...                                                 ...
# 1015                                     No Rear Camera
# 1016                     32 MP Rear & 5 MP Front Camera
# 1017  50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front ...
# 1018        50 MP + 8 MP Dual Rear & 50 MP Front Camera
# 1019        50 MP + 8 MP Dual Rear & 50 MP Front Camera
#
#                            card           os
# 0                   Android v16  No FM Radio
# 1     Memory Card Not Supported  Android v15
# 2     Memory Card Not Supported  Android v16
# 3                   Android v16  No FM Radio
# 4                   Android v16  No FM Radio
# ...                         ...          ...
# 1015       Memory Card (Hybrid)  No FM Radio
# 1016       Memory Card (Hybrid)  Android v15
# 1017                Android v14  No FM Radio
# 1018                Android v15  No FM Radio
# 1019                Android v15  No FM Radio
#
# [1020 rows x 11 columns]
